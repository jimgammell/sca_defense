# %%
import os
import torch
from torch import nn, optim
from run_adversarial_trial import run_trial, plot_results

save_dir = os.path.join('.', 'results', 'adv_trial_test')
kwargs = {
    'batch_size': 512,
    'device': 'cuda' if torch.cuda.is_available() else 'cpu',
    'disc_pretrain_epochs': 2,
    'gen_pretrain_epochs': 2,
    'train_epochs': 2,
    'eval_disc_posttrain_epochs': 2,
    'disc_sn': True,
    'gen_sn': True,
    'gen_loss_fn': nn.MSELoss(),
    'ce_eps': 1e-5,
    'ce_warmup_iter': 100,
    'ce_max_iter': 1000,
    'ce_opt': optim.Adam,
    'ce_opt_kwargs': {'lr': 1e-2},
    'project_rec_updates': True,
    'loss_mixture_coefficient': 0.01,
    'ind_eval_disc': True,
    'save_dir': save_dir
}

# %%
from run_adversarial_trial import run_trial

run_trial(**kwargs)
# Out:
# Saving to ./results/adv_trial_test
# Using MNIST saved at ./downloads/MNIST
# Train dataset: Dataset WatermarkedMNIST
#     Number of datapoints: 60000
#     Root location: ./downloads/MNIST
#     Split: Train
# Test dataset: Dataset WatermarkedMNIST
#     Number of datapoints: 10000
#     Root location: ./downloads/MNIST
#     Split: Test
# Train dataloader: <torch.utils.data.dataloader.DataLoader object at 0x7fbfbad7c310>
# Test dataloader: <torch.utils.data.dataloader.DataLoader object at 0x7fbfb854b370>
# Disc: LeNet5Classifier(
#   (model): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#       (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#       (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Sequential(
#       (0): Linear(in_features=256, out_features=120, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=120, out_features=84, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=84, out_features=2, bias=True)
#     )
#   )
# )
# Gen: LeNet5Autoencoder(
#   (feature_extractor): Sequential(
#     (0): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#     (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (mixer): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=256, bias=True)
#   )
#   (reconstructor): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): ConvTranspose2d(16, 6, kernel_size=(5, 5), stride=(1, 1))
#     (2): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Upsample(scale_factor=2.0, mode=nearest)
#     (5): ConvTranspose2d(6, 6, kernel_size=(5, 5), stride=(1, 1))
#     (6): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): ConvTranspose2d(6, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# Disc opt: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.5, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Gen opt: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Disc loss fn: CrossEntropyLoss()
# Gen loss fn: MSELoss()
# Eval disc: LeNet5Classifier(
#   (model): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#       (1): BatchNorm2d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#       (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Sequential(
#       (0): Linear(in_features=256, out_features=120, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=120, out_features=84, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=84, out_features=2, bias=True)
#     )
#   )
# )
# Eval disc opt: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Eval disc loss fn: CrossEntropyLoss()
#
#
# Pretraining the evaluation discriminator.
#
# Starting epoch 1
# Done training in 1.5216834545135498 seconds
# Done testing in 0.517219066619873 seconds
# Results:
# 	tr_pt_eval_disc_loss: 0.5832982659339905
# 	tr_pt_eval_disc_acc: 0.6765371204096045
# 	te_pt_eval_disc_loss: 0.40931254625320435
# 	te_pt_eval_disc_acc: 0.8129653033088236
#
# Starting epoch 2
# Done training in 1.3650212287902832 seconds
# Done testing in 0.49582457542419434 seconds
# Results:
# 	tr_pt_eval_disc_loss: 0.2593022882938385
# 	tr_pt_eval_disc_acc: 0.8919988082627118
# 	te_pt_eval_disc_loss: 0.16644668579101562
# 	te_pt_eval_disc_acc: 0.9320714613970589
#
#
# Pretraining the discriminator.
#
# Starting epoch 1
# Done training in 1.5276989936828613 seconds
# Done testing in 0.4428584575653076 seconds
# Results:
# 	tr_pt_eval_disc_loss: 0.2593022882938385
# 	tr_pt_eval_disc_acc: 0.8919988082627118
# 	te_pt_eval_disc_loss: 0.16644668579101562
# 	te_pt_eval_disc_acc: 0.9320714613970589
# 	tr_pt_disc_loss: 0.585345447063446
# 	tr_pt_disc_acc: 0.6736515713276836
# 	te_pt_disc_loss: 0.7716187238693237
# 	te_pt_disc_acc: 0.5859834558823529
#
# Starting epoch 2
# Done training in 1.5499789714813232 seconds
# Done testing in 0.4405555725097656 seconds
# Results:
# 	tr_pt_eval_disc_loss: 0.2593022882938385
# 	tr_pt_eval_disc_acc: 0.8919988082627118
# 	te_pt_eval_disc_loss: 0.16644668579101562
# 	te_pt_eval_disc_acc: 0.9320714613970589
# 	tr_pt_disc_loss: 0.3169022500514984
# 	tr_pt_disc_acc: 0.8684840660310735
# 	te_pt_disc_loss: 0.21339145302772522
# 	te_pt_disc_acc: 0.92421875
#
#
# Pretraining the generator.
#
# Starting epoch 1
# Done training in 2.585505723953247 seconds
# Done testing in 0.5087053775787354 seconds
# Results:
# 	tr_pt_eval_disc_loss: 0.2593022882938385
# 	tr_pt_eval_disc_acc: 0.8919988082627118
# 	te_pt_eval_disc_loss: 0.16644668579101562
# 	te_pt_eval_disc_acc: 0.9320714613970589
# 	tr_pt_disc_loss: 0.3169022500514984
# 	tr_pt_disc_acc: 0.8684840660310735
# 	te_pt_disc_loss: 0.21339145302772522
# 	te_pt_disc_acc: 0.92421875
# 	tr_pt_gen_loss: 0.24424393475055695
# 	te_pt_gen_loss: 0.15586481988430023
#
# Starting epoch 2
# Done training in 2.6018877029418945 seconds
# Done testing in 0.47889137268066406 seconds
# Results:
# 	tr_pt_eval_disc_loss: 0.2593022882938385
# 	tr_pt_eval_disc_acc: 0.8919988082627118
# 	te_pt_eval_disc_loss: 0.16644668579101562
# 	te_pt_eval_disc_acc: 0.9320714613970589
# 	tr_pt_disc_loss: 0.3169022500514984
# 	tr_pt_disc_acc: 0.8684840660310735
# 	te_pt_disc_loss: 0.21339145302772522
# 	te_pt_disc_acc: 0.92421875
# 	tr_pt_gen_loss: 0.13771072030067444
# 	te_pt_gen_loss: 0.12418586015701294
#
#
# Training the system.
#
# Starting epoch 1
# Done training in 85.82912516593933 seconds
# Done testing in 13.833399295806885 seconds
# Results:
# 	tr_pt_eval_disc_loss: 0.2593022882938385
# 	tr_pt_eval_disc_acc: 0.8919988082627118
# 	te_pt_eval_disc_loss: 0.16644668579101562
# 	te_pt_eval_disc_acc: 0.9320714613970589
# 	tr_pt_disc_loss: 0.3169022500514984
# 	tr_pt_disc_acc: 0.8684840660310735
# 	te_pt_disc_loss: 0.21339145302772522
# 	te_pt_disc_acc: 0.92421875
# 	tr_pt_gen_loss: 0.13771072030067444
# 	te_pt_gen_loss: 0.12418586015701294
# 	tr_gen_adv_loss: 0.04426611587405205
# 	tr_gen_rec_loss: 0.2401404231786728
# 	tr_confusing_example_loss: 0.6931519508361816
# 	tr_disc_loss: 0.7035187482833862
# 	tr_disc_acc: 0.5092138947740114
# 	tr_eval_disc_loss: 0.7314987182617188
# 	tr_eval_disc_acc: 0.5256664901129944
# 	te_confusing_example_loss: 0.6931918859481812
# 	te_disc_loss: 0.693217396736145
# 	te_disc_acc: 0.49469209558823535
# 	te_gen_adv_loss: 0.03593408316373825
# 	te_gen_rec_loss: 0.19705399870872498
# 	te_eval_disc_loss: 0.7002965211868286
# 	te_eval_disc_acc: 0.5044921875
#
# Starting epoch 2
# Done training in 115.24096775054932 seconds
# Done testing in 15.224753379821777 seconds
# Results:
# 	tr_pt_eval_disc_loss: 0.2593022882938385
# 	tr_pt_eval_disc_acc: 0.8919988082627118
# 	te_pt_eval_disc_loss: 0.16644668579101562
# 	te_pt_eval_disc_acc: 0.9320714613970589
# 	tr_pt_disc_loss: 0.3169022500514984
# 	tr_pt_disc_acc: 0.8684840660310735
# 	te_pt_disc_loss: 0.21339145302772522
# 	te_pt_disc_acc: 0.92421875
# 	tr_pt_gen_loss: 0.13771072030067444
# 	te_pt_gen_loss: 0.12418586015701294
# 	tr_gen_adv_loss: 0.051271867007017136
# 	tr_gen_rec_loss: 0.17704488337039948
# 	tr_confusing_example_loss: 0.6933404207229614
# 	tr_disc_loss: 0.6932417154312134
# 	tr_disc_acc: 0.5043255649717514
# 	tr_eval_disc_loss: 0.688431978225708
# 	tr_eval_disc_acc: 0.5407176906779662
# 	te_confusing_example_loss: 0.693198025226593
# 	te_disc_loss: 0.6931187510490417
# 	te_disc_acc: 0.5042681525735294
# 	te_gen_adv_loss: 0.03038112260401249
# 	te_gen_rec_loss: 0.12147627025842667
# 	te_eval_disc_loss: 0.6852351427078247
# 	te_eval_disc_acc: 0.5528377757352941
# Posttraining the evaluation discriminator.
#
# Starting epoch 1
# Done training in 3.332875967025757 seconds
# Done testing in 0.5070648193359375 seconds
# Results:
# 	tr_pt_eval_disc_loss: 0.2593022882938385
# 	tr_pt_eval_disc_acc: 0.8919988082627118
# 	te_pt_eval_disc_loss: 0.16644668579101562
# 	te_pt_eval_disc_acc: 0.9320714613970589
# 	tr_pt_disc_loss: 0.3169022500514984
# 	tr_pt_disc_acc: 0.8684840660310735
# 	te_pt_disc_loss: 0.21339145302772522
# 	te_pt_disc_acc: 0.92421875
# 	tr_pt_gen_loss: 0.13771072030067444
# 	te_pt_gen_loss: 0.12418586015701294
# 	tr_gen_adv_loss: 0.051271867007017136
# 	tr_gen_rec_loss: 0.17704488337039948
# 	tr_confusing_example_loss: 0.6933404207229614
# 	tr_disc_loss: 0.6932417154312134
# 	tr_disc_acc: 0.5043255649717514
# 	tr_eval_disc_loss: 0.688431978225708
# 	tr_eval_disc_acc: 0.5407176906779662
# 	te_confusing_example_loss: 0.693198025226593
# 	te_disc_loss: 0.6931187510490417
# 	te_disc_acc: 0.5042681525735294
# 	te_gen_adv_loss: 0.03038112260401249
# 	te_gen_rec_loss: 0.12147627025842667
# 	te_eval_disc_loss: 0.6852351427078247
# 	te_eval_disc_acc: 0.5528377757352941
# 	tr_po_eval_disc_loss: 0.6827899217605591
# 	tr_po_eval_disc_acc: 0.5573413223870057
# 	te_po_eval_disc_loss: 0.677492082118988
# 	te_po_eval_disc_acc: 0.571875
#
# Starting epoch 2
# Done training in 3.2759199142456055 seconds
# Done testing in 0.5376582145690918 seconds
# Results:
# 	tr_pt_eval_disc_loss: 0.2593022882938385
# 	tr_pt_eval_disc_acc: 0.8919988082627118
# 	te_pt_eval_disc_loss: 0.16644668579101562
# 	te_pt_eval_disc_acc: 0.9320714613970589
# 	tr_pt_disc_loss: 0.3169022500514984
# 	tr_pt_disc_acc: 0.8684840660310735
# 	te_pt_disc_loss: 0.21339145302772522
# 	te_pt_disc_acc: 0.92421875
# 	tr_pt_gen_loss: 0.13771072030067444
# 	te_pt_gen_loss: 0.12418586015701294
# 	tr_gen_adv_loss: 0.051271867007017136
# 	tr_gen_rec_loss: 0.17704488337039948
# 	tr_confusing_example_loss: 0.6933404207229614
# 	tr_disc_loss: 0.6932417154312134
# 	tr_disc_acc: 0.5043255649717514
# 	tr_eval_disc_loss: 0.688431978225708
# 	tr_eval_disc_acc: 0.5407176906779662
# 	te_confusing_example_loss: 0.693198025226593
# 	te_disc_loss: 0.6931187510490417
# 	te_disc_acc: 0.5042681525735294
# 	te_gen_adv_loss: 0.03038112260401249
# 	te_gen_rec_loss: 0.12147627025842667
# 	te_eval_disc_loss: 0.6852351427078247
# 	te_eval_disc_acc: 0.5528377757352941
# 	tr_po_eval_disc_loss: 0.6758816838264465
# 	tr_po_eval_disc_acc: 0.571631135240113
# 	te_po_eval_disc_loss: 0.6717573404312134
# 	te_po_eval_disc_acc: 0.5805376838235294

# %%
from run_adversarial_trial import plot_results

plot_results(save_dir)
