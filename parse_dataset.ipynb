# %%
from dataset import AesSingleKeyDataset

Datasets = {}
for key in range(16):
    Datasets.update({key: AesSingleKeyDataset(key=key, data_path='./data')})
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 256/256 [00:00<00:00, 9134.19it/s]
# Processing data for byte 0...
# Processing data for byte 1...
# Processing data for byte 2...
# Processing data for byte 3...
# Processing data for byte 4...
# Processing data for byte 5...
# ...
#   0%|                                                                                          | 0/256 [00:00<?, ?it/s]
# Processing data for byte 6...
# Processing data for byte 7...
# Processing data for byte 8...
# Processing data for byte 9...
# Processing data for byte 10...
# Processing data for byte 11...
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 256/256 [00:00<00:00, 9143.05it/s]
# Processing data for byte 12...
# Processing data for byte 13...
# Processing data for byte 14...
# Processing data for byte 15...
# ...

# %%
print([len(Datasets[k]) for k in Datasets])
# Out:
# [632, 632, 632, 632, 632, 632, 632, 632, 632, 632, 632, 632, 632, 632, 632, 632]
