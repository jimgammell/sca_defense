# %%
from data import load_shard, load_dataset

# %%
shards = load_dataset([0x0097cec56c8d97796aeb1902edd8ce43])
print(shards)
# Out:
# {788230643560681444460099466746711619: {'traces': array([[-0.1582  , -0.2451  , -0.274   , ..., -0.2886  ,  0.10254 ,
#         -0.1436  ],
#        [-0.1006  , -0.274   , -0.2163  , ..., -0.274   ,  0.0586  ,
#         -0.1582  ],
#        [-0.2593  , -0.2163  , -0.3027  , ..., -0.274   ,  0.000977,
#         -0.11475 ],
#        ...,
#        [-0.2451  , -0.2017  , -0.2886  , ..., -0.3027  ,  0.01563 ,
#         -0.1436  ],
#        [-0.11475 , -0.274   , -0.274   , ..., -0.3027  ,  0.0879  ,
#         -0.1582  ],
#        [-0.3462  , -0.11475 , -0.274   , ..., -0.2305  , -0.2593  ,
#          0.000977]], dtype=float16), 'plaintext': array([ 30,  97, 228,  10,  56, 132,  28,  59,  32, 224,   9, 226,  86,
#         46, 219,  96, 229, 254,  18, 170,  98, 162,  51, 120, 142,  80,
#         49, 180, 163, 153, 253,  88, 238, 186,  64, 215, 176, 122, 144,
#        231, 200, 124,  35, 103,  66, 235, 197,  26,  19, 145, 250, 107,
# ...
